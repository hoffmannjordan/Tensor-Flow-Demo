# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import glob
#import seaborn as sn
import matplotlib.pyplot as plt

# %%
def rgb2gray(rgb):
	r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
	gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
	return gray

# %%
files = glob.glob("/scratch2/Lava/*png")

# %% [markdown]
# ## Look at an image

# %%
name = files[0]
im = Image.open(name)
im = im.resize((512,288))

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=512x288 at 0x7F43E6350410>

# %%
RGB = np.array(im)

# %%
np.shape(RGB)
# Out:
# (288, 512, 3)

# %%
plt.subplot(1, 3, 1)
sn.heatmap(RGB[:,:,0],cmap='Reds')
plt.subplot(1, 3, 2)
sn.heatmap(RGB[:,:,1],cmap='Greens')
plt.subplot(1, 3, 3)
sn.heatmap(RGB[:,:,2],cmap='Blues')

# %% [markdown]
# ## Process Data

# %%
files = glob.glob("/scratch2/Lava/*png")
print len(files)
LL = len(files)
# Out:
# 8681

# %%
x_train = np.zeros((7143,288,256,1))
y_train = np.zeros((7143,288,256,3))

x_test = np.zeros((7143,288,256,1))
y_test = np.zeros((7143,288,256,3))

# %%
files[0]
# Out:
# '/scratch2/Lava/Frame523.png'

# %%
im = Image.open('/scratch2/Lava/Frame'+str(8681)+'.png')

# %%
for i in range(1,7144):
    print i
    name = files[i]
    im = Image.open('/scratch2/Lava/Frame'+str(i)+'.png')
    im = im.resize((512,288))
    RGB = np.array(im)
    gray = rgb2gray(RGB)
    x_train[i] = np.reshape(np.array([gray[:,0:512/2]]),(288,256,1))/255.
    y_train[i] = np.array([RGB[:,0:512/2,:]])/255.
    x_test[i] = np.reshape(np.array([gray[:,512/2:]]),(288,256,1))/255.
    y_test[i] = np.array([RGB[:,512/2:,:]])/255.

# %%
#x_test = np.zeros((LL,288,256,1))
#y_test = np.zeros((LL,288,256,3))

# %%
#for i in range(1,8682):
#    name = files[i]
#    im = Image.open(name)
#    im = im.resize((512,288))
#    RGB = np.array(im)
#    gray = rgb2gray(RGB)
#    x_test[i] = np.reshape(np.array([gray[:,512/2:]]),(288,256,1))/255.
#    y_test[i] = np.array([RGB[:,512/2:,:]])/255.

# %%
x_train[0].shape
# Out:
# (288, 256, 1)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(kernel_size = (3,3), filters = 4, activation='relu',input_shape=(288, 256,1)),
  tf.keras.layers.Conv2D(kernel_size = (3,3), filters = 8, activation='relu'),
  tf.keras.layers.Conv2D(kernel_size = (3,3), filters = 16, activation='relu'),
  tf.keras.layers.Conv2D(kernel_size = (3,3), filters = 32, activation='relu'),
  tf.keras.layers.Conv2DTranspose(kernel_size = (3,3), filters = 32, activation='relu'),
  tf.keras.layers.Conv2DTranspose(kernel_size = (3,3), filters = 16, activation='relu'),
  tf.keras.layers.Conv2DTranspose(kernel_size = (3,3), filters = 8, activation='relu'),
  tf.keras.layers.Conv2DTranspose(kernel_size = (3,3), filters = 3, activation='relu')
])

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(kernel_size = (3,3), filters = 8, activation='relu',input_shape=(288, 256,1)),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(kernel_size = (3,3), filters = 32, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(kernel_size = (3,3), filters = 32, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(kernel_size = (3,3), filters = 64, activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(kernel_size = (3,3), filters = 128, activation='relu'),  
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(kernel_size = (3,3), filters = 128, activation='relu'),          
  tf.keras.layers.Conv2DTranspose(kernel_size = (3,3), filters = 128, activation='relu'),
  tf.keras.layers.BatchNormalization(),
    tf.keras.layers.UpSampling2D(size=(2, 2)),
  tf.keras.layers.Conv2DTranspose(kernel_size = (3,3), filters = 64, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.UpSampling2D(size=(2, 2)),
  tf.keras.layers.Conv2DTranspose(kernel_size = (3,3), filters = 64, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.UpSampling2D(size=(2, 2)),
  tf.keras.layers.Conv2DTranspose(kernel_size = (3,3), filters = 32, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.UpSampling2D(size=(2, 2)),
  tf.keras.layers.Conv2DTranspose(kernel_size = (3,3), filters = 32, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.UpSampling2D(size=(2, 2)),
  tf.keras.layers.Conv2DTranspose(kernel_size = (5,5), filters = 3, activation='relu')
])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 286, 254, 8)       80
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 286, 254, 8)       32
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 143, 127, 8)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 141, 125, 32)      2336
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 141, 125, 32)      128
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 70, 62, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 68, 60, 32)        9248
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 68, 60, 32)        128
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 34, 30, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 14, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 14, 12, 128)       73856
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 7, 6, 128)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 5, 4, 128)         147584
# _________________________________________________________________
# conv2d_transpose_11 (Conv2DT (None, 7, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 7, 6, 128)         512
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 14, 12, 128)       0
# _________________________________________________________________
# conv2d_transpose_12 (Conv2DT (None, 16, 14, 64)        73792
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 16, 14, 64)        256
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 32, 28, 64)        0
# _________________________________________________________________
# conv2d_transpose_13 (Conv2DT (None, 34, 30, 64)        36928
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 34, 30, 64)        256
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 68, 60, 64)        0
# _________________________________________________________________
# conv2d_transpose_14 (Conv2DT (None, 70, 62, 32)        18464
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 70, 62, 32)        128
# _________________________________________________________________
# up_sampling2d_11 (UpSampling (None, 140, 124, 32)      0
# _________________________________________________________________
# conv2d_transpose_15 (Conv2DT (None, 142, 126, 32)      9248
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 142, 126, 32)      128
# _________________________________________________________________
# up_sampling2d_12 (UpSampling (None, 284, 252, 32)      0
# _________________________________________________________________
# conv2d_transpose_16 (Conv2DT (None, 288, 256, 3)       2403
# =================================================================
# Total params: 541,587
# Trainable params: 540,803
# Non-trainable params: 784
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='mean_squared_error')

# %%
model.fit(x_train, y_train, epochs=150)
# Out:
# Epoch 1/150
# 7143/7143 [==============================] - 922s 129ms/step - loss: 0.6091
# Epoch 2/150
# 7143/7143 [==============================] - 924s 129ms/step - loss: 0.1846
# Epoch 3/150
# 7143/7143 [==============================] - 923s 129ms/step - loss: 0.1323
# Epoch 4/150
# 7143/7143 [==============================] - 924s 129ms/step - loss: 0.1063
# Epoch 5/150
# 7143/7143 [==============================] - 926s 130ms/step - loss: 0.0925
# Epoch 6/150
# 7143/7143 [==============================] - 925s 130ms/step - loss: 0.0840
# Epoch 7/150
# 7143/7143 [==============================] - 926s 130ms/step - loss: 0.0745
# Epoch 81/150
# 7143/7143 [==============================] - 981s 137ms/step - loss: 0.0150
# Epoch 82/150
# 7143/7143 [==============================] - 981s 137ms/step - loss: 0.0149
# Epoch 83/150
# 7143/7143 [==============================] - 984s 138ms/step - loss: 0.0148
# Epoch 84/150
# 7143/7143 [==============================] - 989s 138ms/step - loss: 0.0149
# Epoch 85/150
# 7143/7143 [==============================] - 993s 139ms/step - loss: 0.0149
# Epoch 86/150
# 7143/7143 [==============================] - 981s 137ms/step - loss: 0.0146
# Epoch 87/150
# 7143/7143 [==============================] - 983s 138ms/step - loss: 0.0146
# Epoch 88/150
# 7143/7143 [==============================] - 972s 136ms/step - loss: 0.0144
# Epoch 89/150
# 7143/7143 [==============================] - 975s 136ms/step - loss: 0.0143
# Epoch 90/150
# 7143/7143 [==============================] - 976s 137ms/step - loss: 0.0141
# Epoch 91/150
# 7143/7143 [==============================] - 970s 136ms/step - loss: 0.0142
# Epoch 92/150
# 7143/7143 [==============================] - 974s 136ms/step - loss: 0.0143
# Epoch 93/150
# 7143/7143 [==============================] - 975s 137ms/step - loss: 0.0143
# Epoch 94/150
# 1792/7143 [======>.......................] - ETA: 12:09 - loss: 0.0141
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-6f0e193c2157> in <module>()
# ----> 1 model.fit(x_train, y_train, epochs=150)
#
# /home/jordan/anaconda2/lib/python2.7/site-packages/tensorflow/python/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1637           initial_epoch=initial_epoch,
#    1638           steps_per_epoch=steps_per_epoch,
# -> 1639           validation_steps=validation_steps)
#    1640
#    1641   def evaluate(self,
#
# /home/jordan/anaconda2/lib/python2.7/site-packages/tensorflow/python/keras/engine/training_arrays.pyc in fit_loop(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps)
#     213           ins_batch[i] = ins_batch[i].toarray()
#     214
# --> 215         outs = f(ins_batch)
#     216         if not isinstance(outs, list):
#     217           outs = [outs]
#
# /home/jordan/anaconda2/lib/python2.7/site-packages/tensorflow/python/keras/backend.pyc in __call__(self, inputs)
#    2984
#    2985     fetched = self._callable_fn(*array_vals,
# -> 2986                                 run_metadata=self.run_metadata)
#    2987     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2988     return fetched[:len(self.outputs)]
#
# /home/jordan/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
res=model.predict(np.array([x_train[1000]]))[0]

# %%
res=model.predict(x_test)

# %%
plt.imshow(np.array(y_test[120]))
plt.show()

# %%
Image.fromarray(np.array(255*y_test[1200]).astype('uint8')).convert('LA')
# Out:
# <PIL.Image.Image image mode=LA size=256x288 at 0x7F43D4DEE7D0>

# %%
np.shape(res)
# Out:
# (7143, 288, 256, 3)

# %%
np.save('/scratch/resLATE_T.npy',res)

# %%
sn.heatmap(res[:,:,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-3bb0b60b7779> in <module>()
# ----> 1 sn.heatmap(res[:,:,1])
#
# NameError: name 'sn' is not defined

# %%
resPLOT=res[0]*255

# %%
resRI=resPLOT.astype('uint8')

# %%
imagesave = Image.fromarray(resRI)

# %%
imagesave.save('/scratch/LL_'+str(1)+'.png')

# %%
for x in range(len(res)):
    resPLOT=res[x]*255
    resRI=resPLOT.astype('uint8')
    imagesave = Image.fromarray(resRI)
    imagesave.save('/scratch/LLLT_'+str(x)+'.png')

# %%
files[589]
# Out:
# '/scratch2/Lava/Frame5135.png'

# %%
for x in range(len(res)):
    IM = Image.fromarray(np.array(255*y_train[x]).astype('uint8')).convert('LA')
    IM.save('/scratch/LLLTGY_'+str(x)+'.png')
